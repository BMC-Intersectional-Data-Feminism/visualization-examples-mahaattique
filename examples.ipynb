# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('spotify.csv')
# df

plt.plot(df['Date'], df['Shape of You'], label = 'Shape of You')
plt.plot(df['Date'], df['Despacito'], label = 'Despacito')
plt.legend()
plt.xlabel('Dates')
plt.ylabel('Streams')

# fig, ax = plt.subplots()
# ax.plot(df['Date'], df['Shape of You'])

# x_ticks = list(df['Date'])
# x_labels = 
# ax.set_xticks(df['Date'], rotation='vertical')
# Out:
# Text(0, 0.5, 'Streams')
